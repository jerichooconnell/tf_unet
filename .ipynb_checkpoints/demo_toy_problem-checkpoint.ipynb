# %%
from __future__ import division, print_function
# %load_ext autoreload
# %autoreload 2
# %matplotlib
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
plt.rcParams['image.cmap'] = 'gist_earth'

from tf_unet import image_gen
from tf_unet import unet
from tf_unet import util

nx = 512
ny = 512

generator = image_gen.get_image_gen(nx, ny, cnt=100)

x_test, y_test = generator(4)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Using matplotlib backend: Qt5Agg

# %%
# %matplotlib qt
fig, ax = plt.subplots(1,2, sharey=True, figsize=(8,4))
ax[0].imshow(x_test[0,...,0], aspect="auto")
ax[1].imshow(y_test[0,...,1], aspect="auto")
print(type(x_test[0,0,0,0]))
print(type(y_test[0,0,0,0]))
# Out:
# <class 'numpy.float64'>
# <class 'numpy.float64'>

# %%
net = unet.Unet(channels=generator.channels, n_class=generator.n_class, layers=3, features_root=16)
# Out:
# Layers 3, features 16, filter size 3x3, pool size: 2x2
# WARNING:tensorflow:From /home/jericho/ML_medphys/tf_unet/tf_unet/unet.py:199: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# WARNING:tensorflow:From /home/jericho/ML_medphys/tf_unet/tf_unet/layers.py:61: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
trainer = unet.Trainer(net, optimizer="momentum", opt_kwargs=dict(momentum=0.2))

# %%
path = trainer.train(generator, "./unet_trained", training_iters=20, epochs=2, display_step=2)
# Out:
# WARNING:tensorflow:From /home/jericho/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:118: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Removing '/home/jericho/ML_medphys/tf_unet/prediction'
# Removing '/home/jericho/ML_medphys/tf_unet/unet_trained'
# Allocating '/home/jericho/ML_medphys/tf_unet/prediction'
# Allocating '/home/jericho/ML_medphys/tf_unet/unet_trained'
# Verification error= 44.9%, loss= 0.8740
# Start optimization
# Iter 0, Minibatch Loss= 0.8331, Training Accuracy= 0.7828, Minibatch error= 21.7%
# Iter 2, Minibatch Loss= 0.8266, Training Accuracy= 0.7072, Minibatch error= 29.3%
# Iter 4, Minibatch Loss= 0.7781, Training Accuracy= 0.7963, Minibatch error= 20.4%
# Iter 6, Minibatch Loss= 0.9070, Training Accuracy= 0.4891, Minibatch error= 51.1%
# Iter 8, Minibatch Loss= 0.8113, Training Accuracy= 0.6823, Minibatch error= 31.8%
# Iter 10, Minibatch Loss= 0.6598, Training Accuracy= 0.8953, Minibatch error= 10.5%
# Iter 12, Minibatch Loss= 0.6802, Training Accuracy= 0.8377, Minibatch error= 16.2%
# Iter 14, Minibatch Loss= 0.7214, Training Accuracy= 0.7766, Minibatch error= 22.3%
# Iter 16, Minibatch Loss= 0.6865, Training Accuracy= 0.8071, Minibatch error= 19.3%
# Iter 18, Minibatch Loss= 0.9003, Training Accuracy= 0.5859, Minibatch error= 41.4%
# Epoch 0, Average loss: 0.7762, learning rate: 0.2000
# Verification error= 38.3%, loss= 0.8823
# Iter 20, Minibatch Loss= 0.5607, Training Accuracy= 0.9056, Minibatch error= 9.4%
# Iter 22, Minibatch Loss= 0.8808, Training Accuracy= 0.6181, Minibatch error= 38.2%
# Iter 24, Minibatch Loss= 0.6303, Training Accuracy= 0.8546, Minibatch error= 14.5%
# Iter 26, Minibatch Loss= 0.7025, Training Accuracy= 0.7855, Minibatch error= 21.5%
# Iter 28, Minibatch Loss= 0.5109, Training Accuracy= 0.9680, Minibatch error= 3.2%
# Iter 30, Minibatch Loss= 0.7993, Training Accuracy= 0.6959, Minibatch error= 30.4%
# Iter 32, Minibatch Loss= 0.6786, Training Accuracy= 0.8098, Minibatch error= 19.0%
# Iter 34, Minibatch Loss= 0.7862, Training Accuracy= 0.7040, Minibatch error= 29.6%
# Iter 36, Minibatch Loss= 0.9031, Training Accuracy= 0.5861, Minibatch error= 41.4%
# Iter 38, Minibatch Loss= 0.5740, Training Accuracy= 0.9090, Minibatch error= 9.1%
# Epoch 1, Average loss: 0.7345, learning rate: 0.1900
# Verification error= 38.3%, loss= 0.8943
# Optimization Finished!

# %%
prediction = net.predict("./unet_trained/model.cpkt", x_test)
# Out:
# INFO:tensorflow:Restoring parameters from ./unet_trained/model.cpkt
# Model restored from file: ./unet_trained/model.cpkt

# %%
# %matplotlib inline
fig, ax = plt.subplots(2, 3, sharex=True, sharey=True, figsize=(12,8))
for i in range(ax.shape[0]):
    ax[i, 0].imshow(x_test[i,...,0], aspect="auto")
    ax[i, 1].imshow(y_test[i,...,1], aspect="auto")
    mask = prediction[i,...,1] > 0.9
    ax[i, 2].imshow(mask, aspect="auto")
ax[0, 0].set_title("Input")
ax[0, 1].set_title("Ground truth")
ax[0, 2].set_title("Prediction")
fig.tight_layout()
fig.savefig("docs/toy_problem.png")
